# %% [markdown]
# **Exercício 4**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import quad

# %% [markdown]
# Letra a)

# %%
n = [7,10]
da = 0 
db = 1
xa = 0.2
xb = 0.3

def f(xm,xa,xb):
    if (xm <= xb) & (xm >= xa): return 1
    else: return 0

plt.figure()
plt.grid(alpha=0.3)
plt.xlabel('x')
plt.ylabel('u(x)')

U = []

for j in range(2):
    delta = (db-da)/n[j]
    x = np.linspace(da,db,n[j]+1)
    xm = np.linspace(da+delta/2, db-delta/2, n[j])
    A = np.zeros((n[j],n[j]))
    b = np.zeros(n[j])

    for i in range(n[j]):
        b[i] = f(xm[i],xa,xb)
        for k in range(n[j]):
            jj = k + 1
            A[i, k] = jj * (jj + 1) * xm[i]**(jj - 1)

    alpha = np.linalg.solve(A,b)

    u = np.zeros(n[j]+1)
    for i in range(n[j]+1):
        u[i] = np.sum(alpha * (x[i] - x[i]**(np.arange(1,n[j]+1)+1)))

    plt.plot(x,u,'o',ls='-',label=f'n = {n[j]}')
    U.append(u.copy())

plt.title('Point Matching Method')
plt.legend()
plt.show()

# %% [markdown]
# A matriz A para n = 20 fica extremamente mal condicionada.

# %% [markdown]
# Letra b)

# %%
plt.figure()
plt.grid(alpha=0.3)
plt.xlabel('x')
plt.ylabel('u(x)')

for j in range(2):
    delta = (db-da)/n[j]
    x = np.linspace(da,db,n[j]+1)
    xm = np.linspace(da+delta/2, db-delta/2, n[j])
    A = np.zeros((n[j],n[j]))
    b = np.zeros(n[j])

    for i in range(n[j]):
        b[i] = quad(lambda x: f(x,xa,xb),x[i],x[i+1])[0]
        for k in range(n[j]):
            jj = k + 1
            A[i, k] = (jj + 1) * (x[i+1]**jj - x[i]**jj)

    alpha = np.linalg.solve(A,b)

    u = np.zeros(n[j]+1)
    for i in range(1,n[j]+1):
        u[i] = np.sum(alpha * (x[i] - x[i]**(np.arange(1,n[j]+1)+1)))

    plt.plot(x,u,'o',ls='-',label=f'n = {n[j]}')
    U.append(u.copy())

plt.title('Subdomain Collocation Method')
plt.legend()
plt.show()

# %% [markdown]
# Letra c)

# %%
plt.figure()
plt.grid(alpha=0.3)
plt.xlabel('x')
plt.ylabel('u(x)')

for j in range(2):
    delta = (db-da)/n[j]
    x = np.linspace(da,db,n[j]+1)
    xm = np.linspace(da+delta/2, db-delta/2, n[j])
    A = np.zeros((n[j],n[j]))
    b = np.zeros(n[j])

    for i in range(n[j]):
        ii = i + 1
        b[i] = ((xb**2 - xa**2) / 2- (xb**(ii + 2) - xa**(ii + 2))/ (ii + 2))

    for i in range(n[j]):
        ii = i + 1
        for k in range(n[j]):
            jj = k + 1
            A[i, k] = ((ii + 1) * (jj + 1)/ (ii + jj + 1) - 1)

    alpha = np.linalg.solve(A,b)

    u = np.zeros(n[j]+1)
    for i in range(1,n[j]+1):
        u[i] = np.sum(alpha * (x[i] - x[i]**(np.arange(1,n[j]+1)+1)))

    plt.plot(x,u,'o',ls='-',label=f'n = {n[j]}')
    U.append(u.copy())

plt.title('Galerkin Method')
plt.legend()
plt.show()

# %% [markdown]
# Letra d)

# %%
x = np.linspace(da,db,10+1)

plt.figure()
plt.grid(alpha=0.3)
plt.xlabel('x')
plt.ylabel('u(x)')
plt.plot(x,U[1],'o',ls='-',label=f'Point Matching')
plt.plot(x,U[3],'o',ls='--',label=f'Pulse Collocation')
plt.plot(x,U[5],'o',ls='-.',label=f'Galerkin')
plt.title('n = 10')
plt.legend()
plt.show()
